# %%
import numpy as np
import pandas as pd
# from google.colab import drive
# import pandas as pd
# drive.mount('/content/drive')

# import os
twitter = pd.read_csv("/Users/michalkielkowski/Desktop/infa-all/magisterka/eksploracja_danych/Twitter_Sentiment_Analysis/data/twitter_outer_sentiment(1).csv", encoding='ISO-8859-1')

# %%
len(twitter)

sentiment_calculated = []

with open(r'/Users/michalkielkowski/Desktop/infa-all/magisterka/eksploracja_danych/Twitter_Sentiment_Analysis/data/1599kList.txt', 'r') as fp:
    for line in fp:
        # remove linebreak from a current name
        # linebreak is the last character of each line
        x = line[:-1]

        # add current item to the list
        sentiment_calculated.append(int(x))

# %%
DATASET_COLUMNS = ["target", "ids", "date", "flag", "user", "text"]
DATASET_ENCODING = "ISO-8859-1"
twitter = pd.read_csv('/Users/michalkielkowski/Desktop/infa-all/magisterka/eksploracja_danych/Twitter_Sentiment_Analysis/data/training.1600000.processed.noemoticon.csv',encoding=DATASET_ENCODING , names=DATASET_COLUMNS)
twitter.head(5)
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
twitter.head(5)
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
print(len(twitter))
sentiment_calculated.append(-1)
print(len(sentiment_calculated))

twitter.head(5)
# Out:
# 1600000
# 1600000
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
twitter = twitter.drop(twitter.columns[[1,3]], axis=1)
twitter.columns.values[0] = "sentiment"
twitter.columns.values[1] = "date"
twitter.columns.values[2] = "username"
twitter.columns.values[3] = "tweet"
twitter['outer_sentiment'] = sentiment_calculated
twitter.head(5)
# Out:
#    sentiment                          date         username  \
# 0          0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_
# 1          0  Mon Apr 06 22:19:49 PDT 2009    scotthamilton
# 2          0  Mon Apr 06 22:19:53 PDT 2009         mattycus
# 3          0  Mon Apr 06 22:19:57 PDT 2009          ElleCTF
# 4          0  Mon Apr 06 22:19:57 PDT 2009           Karoli
#
#                                                tweet  outer_sentiment
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...                0
# 1  is upset that he can't update his Facebook by ...                2
# 2  @Kenichan I dived many times for the ball. Man...                0
# 3    my whole body feels itchy and like its on fire                 0
# 4  @nationwideclass no, it's not behaving at all....                2

# %%
# twitter.to_csv('twitter_outer_sentiment.csv')

# %%
# removing stopwords

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer

nltk.download('stopwords')
nltk.download('punkt')

stop_words_cached = stopwords.words('english')
tk = TweetTokenizer()


import re
WORD = re.compile(r"")
def regTokenize(text):
    words = WORD.findall(text)
    return words

tokenized_twitter = twitter.copy()
tokenized_twitter.head(5)

tokenized_twitter["tweet"] = tokenized_twitter["tweet"].apply(tk.tokenize)
tokenized_twitter.head(5)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/michalkielkowski/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/michalkielkowski/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#    sentiment                          date         username  \
# 0          0  Mon Apr 06 22:19:45 PDT 2009  _TheSpecialOne_
# 1          0  Mon Apr 06 22:19:49 PDT 2009    scotthamilton
# 2          0  Mon Apr 06 22:19:53 PDT 2009         mattycus
# 3          0  Mon Apr 06 22:19:57 PDT 2009          ElleCTF
# 4          0  Mon Apr 06 22:19:57 PDT 2009           Karoli
#
#                                                tweet  outer_sentiment
# 0  [@switchfoot, http://twitpic.com/2y1zl, -, Aww...                0
# 1  [is, upset, that, he, can't, update, his, Face...                2
# 2  [@Kenichan, I, dived, many, times, for, the, b...                0
# 3  [my, whole, body, feels, itchy, and, like, its...                0
# 4  [@nationwideclass, no, ,, it's, not, behaving,...                2

# %%
dict_mentions = {}
dict_positive_mentions = {}
dict_negative_mentions = {}
dict_neutral_mentions = {}

for idx, row in enumerate(tokenized_twitter['tweet']):

  for word in row:
    if word[0] == '@' and word != '@':
      if word in dict_mentions:
        dict_mentions[word] = dict_mentions[word] + 1
      else:
        dict_mentions[word] = 1
      if tokenized_twitter['outer_sentiment'][idx] == 0:
        if word in dict_negative_mentions:
          dict_negative_mentions[word] = dict_negative_mentions[word] + 1
        else:
          dict_negative_mentions[word] = 1
      if tokenized_twitter['outer_sentiment'][idx] == 2:
        if word in dict_neutral_mentions:
         dict_neutral_mentions[word] = dict_neutral_mentions[word] + 1
        else:
          dict_neutral_mentions[word] = 1
      if tokenized_twitter['outer_sentiment'][idx] == 4:
        if word in dict_positive_mentions:
          dict_positive_mentions[word] = dict_positive_mentions[word] + 1
        else:
          dict_positive_mentions[word] = 1

user = []
mentions = []

user_positive = []
positive_mentions = []

user_negative = []
negative_mentions = []

user_neutral = []
neutral_mentions = []

print(positive_mentions)

for key in dict_mentions.keys():
  user.append(key)
  mentions.append(dict_mentions[key])

for key in dict_positive_mentions.keys():
  user_positive.append(key)
  positive_mentions.append(dict_positive_mentions[key])

for key in dict_negative_mentions.keys():
  user_negative.append(key)
  negative_mentions.append(dict_negative_mentions[key])

for key in dict_neutral_mentions.keys():
  user_neutral.append(key)
  neutral_mentions.append(dict_neutral_mentions[key])
# Out:
# []

# %%
print(dict_neutral_mentions.keys())
# Out:
# dict_keys(['@nationwideclass', '@Kwesidei', '@LOLTrish', '@Tatiana_K', '@LettyA', '@julieebaby', '@fleurylis', '@Viennah', '@BatManYNG', '@katortiz', '@Lt_Algonquin', '@januarycrimson', '@stark', '@mangaaa', '@kpreyes', '@Henkuyinepu', '@marykatherine_q', '@chelserlynn', '@Knights_', '@ozesteph1992', '@jonathanchard', '@RyanSeacrest', '@dannyvegasbaby', '@DjAlizay', '@MySteezRadio', '@GuruMN', '@DonnieWahlberg', '@ircmaxell', '@MyConnecticut', '@CaitlinOConnor', '@miss_om', '@mandayyy', '@Brandizzzle08', '@kissability', '@fishmouse', '@bostongarden', '@LoveMeagan', '@riancurtis', '@KourtneyKardash', '@ridley1013', '@vene2ia', '@MizzChievouz', '@a5hleyf', '@TheLeagueSF', '@Jeffree_Star', '@cococourtney', '@nick_carter', '@nchokkan', '@Poohpot', '@MTUB', '@seblefebvre', '@benackerman', '@carolrainbow', '@danadearmond', '@johnnybeane', '@celycarmo', '@KishoreK', '@RandomlyNat', '@SupaMagg', '@maxime68', '@megelder', '@jillianfish', '@ddlovato', '@David_Henrie', '@ShareThis', '@Appomattox_News', '@jeffreecuntstar', '@lolitariot', '@Miss_Sil', '@JonathanRKnight', '@emmaketurah', '@KelleyRowe', '@sasii', '@ewarden', '@arlenecd', '@heidimontag', '@birutagme', '@danielledeleasa', '@AmandaEnglund', '@nicolerichie', '@thousand_miles', '@clarianne', '@Knot2serious', '@lovebscott', '@lunafiko', '@stephenkruiser', '@Carmonium', '@polhillian', '@tim_grainger', '@ikimb0', '@limbecky', '@Torturedlady', '@PlayRadioPlay', '@deepbluesealove', '@djsoulsister', '@misstoriblack', '@RubyRose1', '@vivekg86', '@hadtobeyou', '@sarahsaturday', '@MTsiaklides', '@winggato', '@JaneBodehouse', '@HoytFortenberry', '@kalichosich', '@kameelahwrites', '@taliasunset', '@yaykimo', '@rj', '@featherinair', '@tomatosalsa', '@brettyboo', '@SLessard', '@mykele', '@astewart87', '@linuxfoundation', '@skylineking722', '@TheBlondeTheory', '@bengottlieb', '@BATMANNN', '@misterphipps', '@vernonhamilton', '@chimpytwit', '@jennlopez', '@hellobebe', '@cloudpimps', '@citizensheep', '@SeaGhostdesigns', '@danphelan', '@normalguyguide', '@BenPritchett', '@OfficialPRofOZ', '@simX', '@Health4UandPets', '@rootbeerfloats8', '@onlysweeter', '@laurwee_boo', '@henrygooden', '@oddchicken', '@cmykevin', '@MissxMarisa', '@danielhalpin', '@kimmyawesome', '@daydee', '@LittleYellowJen', '@onlytosee', '@pealuh', '@mostazzza', '@ryleebeth', '@thecoolestout', '@gaspitsnicole', '@missoliviaa', '@heatherlibby', '@ekim1406', '@NeYawn', '@shresthayash', '@gordonchiu', '@oliyoung', '@riskyrevenge', '@oishiieats', '@razzberrie', '@defsound', '@Coyoteontherun', '@SteveDiamond', '@ItsChelseaStaub', '@marlonjenglish', '@Tubeyornot2B', '@Pixie_Anna', '@CHASEBOOGIE', '@rachaelyamagata', '@rampantheart', '@shalinique', '@Gen_Marie', '@ylizabeth', '@gmg2001', '@Wyldceltic1', '@mrskutcher', '@TexasVegetarian', '@rougeforever', '@thecampingforum', '@CherylTheLibr_n', '@hamporter', '@CandiceNicolePR', '@ShannaMoakler', '@Kailuh', '@darylsws', '@AzPPA', '@lili_marlene', '@brainiacmathew', '@AHolmes_NJ', '@SukottoXD', '@30SECONDSTOMARS', '@grahamcracker', '@sunky', '@innocentdrinks', '@ChauV', '@bkGirlFriday', '@thelmarockz', '@OscarTG', '@trash_kitten', '@Linda_James', '@ktml', '@martiy', '@SuperTim', '@ruthclayton', '@indiblogger', '@louislucci', '@Sir_Almo', '@valonthecoast', '@Kal_Penn', '@imperiusrex', '@babyporridge', '@EvilUnicorn', '@iwouldificould', '@Codylfriend', '@DeiondraSanders', '@KarsentheSlater', '@MissCassandra', '@HoptonHouseBnB', '@derek319', '@shwe370', '@skankityspence', '@awillert', '@msJodiOdie', '@AiyerChitra', '@shelikescute', '@sebby_peek', '@cherrytreerec', '@willadam', '@viennateng', '@roxy_yeah', '@olabini', '@annemarike', '@AllStarNinja', '@Cuckolds', '@xjerx', '@aplusk', '@Juzley', '@mileycyrus', '@FoxWhisperer', '@LOSTmeself', '@eNiBeNi', '@dougiemcfly', '@vishal_ud', '@EllenDeG', '@icedcoffee', '@nixpineda', '@therealswizzz', '@jvmediadesign', '@gerrycoe', '@arhh_', '@skoop', '@cyantist', '@saamx', '@abacab1975', '@kremsersenf', '@TXBrad', '@x0mrsjoejonas', '@breezyskies', '@bivan ...

# %%
mentions2, user2 = (list(t) for t in zip(*sorted(zip(mentions, user), reverse=True)))

positive_mentions2, user_positive2 = (list(t) for t in zip(*sorted(zip(positive_mentions, user_positive), reverse=True)))

negative_mentions2, user_negative2 = (list(t) for t in zip(*sorted(zip(negative_mentions, user_negative), reverse=True)))

neutral_mentions2, user_neutral2 = (list(t) for t in zip(*sorted(zip(neutral_mentions, user_neutral), reverse=True)))

# %%
print(user2[:50])
print(mentions2[:10])

print(user_positive2[:50])
print(positive_mentions2[:10])

print(user_negative2[:50])
print(negative_mentions2[:10])

print(user_neutral2[:50])
print(neutral_mentions2[:10])
# Out:
# ['@mileycyrus', '@tommcfly', '@ddlovato', '@DavidArchie', '@Jonasbrothers', '@jordanknight', '@DonnieWahlberg', '@mitchelmusso', '@JonathanRKnight', '@taylorswift13', '@jonasbrothers', '@selenagomez', '@dougiemcfly', '@peterfacinelli', '@aplusk', '@joeymcintyre', '@Dannymcfly', '@gfalcone601', '@shaundiviney', '@YoungQ', '@kirstiealley', '@TomFelton', '@stephenfry', '@iamdiddy', '@officialTila', '@lilyroseallen', '@ashleytisdale', '@johncmayer', '@AlexAllTimeLow', '@dannywood', '@PerezHilton', '@Pink', '@souljaboytellem', '@andyclemmensen', '@dannygokey', '@markhoppus', '@petewentz', '@TheRealJordin', '@KimKardashian', '@Wossy', '@trent_reznor', '@Alyssa_Milano', '@yelyahwilliams', '@MariahCarey', '@bradiewebbstack', '@katyperry', '@LaurenConrad', '@backstreetboys', '@billyraycyrus', '@nick_carter']
# [4500, 3887, 3466, 1299, 1287, 1129, 1104, 1077, 1074, 1011]
# ['@mileycyrus', '@tommcfly', '@ddlovato', '@DavidArchie', '@Jonasbrothers', '@jordanknight', '@jonasbrothers', '@mitchelmusso', '@JonathanRKnight', '@taylorswift13', '@DonnieWahlberg', '@dougiemcfly', '@selenagomez', '@aplusk', '@Dannymcfly', '@shaundiviney', '@YoungQ', '@peterfacinelli', '@joeymcintyre', '@gfalcone601', '@kirstiealley', '@iamdiddy', '@TomFelton', '@stephenfry', '@johncmayer', '@ashleytisdale', '@lilyroseallen', '@officialTila', '@MariahCarey', '@dannywood', '@dannygokey', '@andyclemmensen', '@markhoppus', '@AlexAllTimeLow', '@TheRealJordin', '@Pink', '@bradiewebbstack', '@trent_reznor', '@Alyssa_Milano', '@petewentz', '@katyperry', '@Wossy', '@PerezHilton', '@souljaboytellem', '@yelyahwilliams', '@billyraycyrus', '@ebassman', '@KimKardashian', '@TraceCyrus', '@mrskutcher']
# [2077, 1613, 1517, 615, 607, 520, 487, 483, 483, 450]
# ['@tommcfly', '@mileycyrus', '@ddlovato', '@DonnieWahlberg', '@Jonasbrothers', '@mitchelmusso', '@DavidArchie', '@jordanknight', '@JonathanRKnight', '@taylorswift13', '@selenagomez', '@dougiemcfly', '@jonasbrothers', '@peterfacinelli', '@joeymcintyre', '@aplusk', '@gfalcone601', '@Dannymcfly', '@PerezHilton', '@YoungQ', '@officialTila', '@AlexAllTimeLow', '@LaurenConrad', '@lilyroseallen', '@stephenfry', '@KimKardashian', '@shaundiviney', '@backstreetboys', '@yelyahwilliams', '@kirstiealley', '@petewentz', '@mcflyharry', '@TomFelton', '@dannywood', '@shanedawson', '@markhoppus', '@Pink', '@souljaboytellem', '@andyclemmensen', '@donniewahlberg', '@johncmayer', '@TheEllenShow', '@dannygokey', '@Wossy', '@SongzYuuup', '@ashleytisdale', '@twitter', '@jonaskevin', '@babygirlparis', '@iamdiddy']
# [1064, 991, 872, 326, 284, 275, 268, 264, 241, 233]
# ['@mileycyrus', '@tommcfly', '@ddlovato', '@DavidArchie', '@Jonasbrothers', '@JonathanRKnight', '@DonnieWahlberg', '@jordanknight', '@taylorswift13', '@mitchelmusso', '@jonasbrothers', '@selenagomez', '@dougiemcfly', '@peterfacinelli', '@joeymcintyre', '@aplusk', '@gfalcone601', '@shaundiviney', '@Dannymcfly', '@YoungQ', '@souljaboytellem', '@TomFelton', '@kirstiealley', '@stephenfry', '@ashleytisdale', '@iamdiddy', '@johncmayer', '@TheRealJordin', '@dannywood', '@Wossy', '@Pink', '@trent_reznor', '@KimKardashian', '@Alyssa_Milano', '@petewentz', '@billyraycyrus', '@PerezHilton', '@AlexAllTimeLow', '@lilyroseallen', '@officialTila', '@dannygokey', '@andyclemmensen', '@yelyahwilliams', '@babygirlparis', '@RyanSeacrest', '@8', '@markhoppus', '@katyperry', '@MariahCarey', '@LaurenConrad']
# [1432, 1210, 1077, 416, 396, 350, 347, 345, 328, 319]

# %%
import matplotlib.pyplot as plt
import numpy as np


positive_data = []
neutral_data = []
negative_data = []

for user in user2[:50]:
  positive_data.append(dict_positive_mentions.get(user, 0))
  neutral_data.append(dict_neutral_mentions.get(user, 0))
  negative_data.append(dict_negative_mentions.get(user, 0))

plt.figure(figsize=(30,10))
plt.title("Mentions of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user2[:50], mentions2[:50])
plt.plot(user2[:50], mentions2[:50])

for plot in [[positive_data, "green"], [neutral_data, "grey"], [negative_data, "red"]]:
  plt.scatter(user2[:50], plot[0], color=plot[1])
  plt.plot(user2[:50], plot[0], color=plot[1])



plt.legend(['all mentions', None, 'positive mentions', None, 'neutral mentions', None, 'negative mentions', None])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(30,10))
plt.title("Negative mentions of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user_negative2[:50], negative_mentions2[:50], color="red")
plt.plot(user_negative2[:50], negative_mentions2[:50], color="red")

# %%
plt.figure(figsize=(30,10))
plt.title("Neutral mentions of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user_neutral2[:50], neutral_mentions2[:50], color="grey")
plt.plot(user_neutral2[:50], neutral_mentions2[:50], color="grey")

# %%
plt.figure(figsize=(30,10))
plt.title("Positive mentions of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user_positive2[:50], positive_mentions2[:50], color="green")
plt.plot(user_positive2[:50], positive_mentions2[:50], color="green")

# %%
# most tweeting people

dict_tweets = {}
dict_positive_tweets = {}
dict_negative_tweets = {}
dict_neutral_tweets = {}

tweets_with_user = zip(twitter['username'], twitter['outer_sentiment'])

for user, sentiment in tweets_with_user:
  if user in dict_tweets:
    dict_tweets[user] += 1
  else:
    dict_tweets[user] = 1

  if user in dict_positive_tweets and sentiment == 4:
    dict_positive_tweets[user] += 1
  else:
    dict_positive_tweets[user] = 1

  if user in dict_neutral_tweets and sentiment == 2:
    dict_neutral_tweets[user] += 1
  else:
    dict_neutral_tweets[user] = 1

  if user in dict_negative_tweets and sentiment == 0:
    dict_negative_tweets[user] += 1
  else:
    dict_negative_tweets[user] = 1


user = []
tweets = []

user_positive = []
positive_tweets = []

user_negative = []
negative_tweets = []

user_neutral = []
neutral_tweets = []

for key in dict_tweets.keys():
  user.append(key)
  tweets.append(dict_tweets[key])

for key in dict_positive_tweets.keys():
  user_positive.append(key)
  positive_tweets.append(dict_positive_tweets[key])

for key in dict_negative_tweets.keys():
  user_negative.append(key)
  negative_tweets.append(dict_negative_tweets[key])

for key in dict_neutral_tweets.keys():
  user_neutral.append(key)
  neutral_tweets.append(dict_neutral_tweets[key])

# %%
tweets2, user2 = (list(t) for t in zip(*sorted(zip(tweets, user), reverse=True)))

positive_tweets2, user_positive_tweets2 = (list(t) for t in zip(*sorted(zip(positive_tweets, user_positive), reverse=True)))

negative_tweets2, user_negative_tweets2 = (list(t) for t in zip(*sorted(zip(negative_tweets, user_negative), reverse=True)))

neutral_tweets2, user_neutral_tweets2 = (list(t) for t in zip(*sorted(zip(neutral_tweets, user_neutral), reverse=True)))

# %%
import matplotlib.pyplot as plt
import numpy as np


positive_data = []
neutral_data = []
negative_data = []

for user in user2[:50]:
  positive_data.append(dict_positive_tweets.get(user, 0))
  neutral_data.append(dict_neutral_tweets.get(user, 0))
  negative_data.append(dict_negative_tweets.get(user, 0))

plt.figure(figsize=(30,10))
plt.title("Tweets of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user2[:50], tweets2[:50])
plt.plot(user2[:50], tweets2[:50])

for plot in [[positive_data, "green"], [neutral_data, "grey"], [negative_data, "red"]]:
  plt.scatter(user2[:50], plot[0], color=plot[1])
  plt.plot(user2[:50], plot[0], color=plot[1])

plt.legend(['all tweets', None, 'positive tweets', None, 'neutral tweets', None, 'negative tweets', None])
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.title("Positive tweets of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user_positive_tweets2[:50], positive_tweets2[:50], color="green")
plt.plot(user_positive_tweets2[:50], positive_tweets2[:50], color="green")
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.title("Negative tweets of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user_negative_tweets2[:50], negative_tweets2[:50], color="red")
plt.plot(user_negative_tweets2[:50], negative_tweets2[:50], color="red")
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.title("Neutral tweets of a given user @handle")
plt.xticks(rotation=90)
plt.scatter(user_neutral_tweets2[:50], neutral_tweets2[:50], color="grey")
plt.plot(user_neutral_tweets2[:50], neutral_tweets2[:50], color="grey")
plt.show()
